# %%
# %run -i GiladGate3q.py
from __future__ import division

# %%
out = dict()

# %%
d = params()
d.gamma = 0.0
d.gec = 0.001
out[len(In)-1] = exper(data=d)
a = out[len(In)-1]
a.data.printParams()
a.pop()
# Out:
# g: 0.100000
# gamma: 0.000000
# gec: 0.001000
# delta: 10.000000

# %%
d = params()
d.gamma = 0.0001
d.gec = 0
out[len(In)-1] = exper(data=d,steps=100)
a = out[len(In)-1]
a.data.printParams()
a.pop()
# Out:
# g: 0.100000
# gamma: 0.000100
# gec: 0.000000
# delta: 10.000000

# %%
a = out[90]
len(a.timelist)
# Out:
# 500

# %%
d = paramsSigma()
d.gamma = 0
out[len(In)-1] = exper(data=d)
a = out[len(In)-1]
a.data.printParams()
a.pop()
# Out:
# g: 0.100000
# gamma: 0.000000
# gec: 1.000000
# delta: 10.000000
