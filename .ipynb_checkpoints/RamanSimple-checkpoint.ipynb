# %%
from qutip import *
from scipy import *
from scipy.signal import argrelextrema
from scipy.optimize import curve_fit
out = dict()

# %%
ket?

# %%
def operate(a,b):
    return vector_to_operator(a*operator_to_vector(b))
def unify(st):
    return st/st.norm()

def ketbra(ket,bra=None):
    if not bra:
        bra = ket
    return ket * bra.dag()

def func(x, a, c, d):
    return a*np.exp(-c*x)+d

def comp(x):
    if x.imag == 0:
        return '({0.real:.2f})'.format(x)
    elif x.real == 0:
        return '({0.imag:.2f}i)'.format(x)
    else:
        return '({0.real:.2f} + {0.imag:.2f}i)'.format(x)

def strket(a):
    return '+'.join([comp(a[i][0][0])+'|{0:03b}>'.format(i) for i in range(8) if a[i]!=0])

def strket(a):
    kett = [unify(ket('110') + ket('000')),unify(ket('110') - ket('000')),ket('100'),ket('010')]
    kett += [unify(ket('111') + ket('001')),unify(ket('111') - ket('001')),ket('101'),ket('011')]
    states = ['|L1>','|L3>','|E1>','|E2>','|O+>','|L2>','|e1>','|e2>']
    a = a.transform(kett)
    return '+'.join([comp(a[i][0][0])+states[i] for i in range(8) if a[i]!=0])
    
def printstates(b):
    eige = b.eigenstates()[0]
    eigstates = b.eigenstates()[1]
    states = [strket(eigstates[i].tidyup(0.001)) for i in range(len(eige)) if norm(eige[i])>0.001 ]
    ens = ['({0.real:.2f})'.format(eige[i]) for i in range(len(eige)) if norm(eige[i])>0.001]
    print '\n'.join(['%s : %s'%(i,j) for (i,j) in zip(ens,states)])
    
L1 = unify(ket('110')+ket('000'))
L2 = unify(ket('111')-ket('001'))
L3 = unify(ket('110')-ket('000'))
I = tensor(qeye(2),qeye(2),qeye(2))

#Error Correction
err = [tensor(sigmax(),qeye(2),qeye(2)),tensor(sigmay(),qeye(2),qeye(2))]
Pe = sum([ketbra(op*L1) + ketbra(op*L2) for op in err])
U = sum([ketbra(op*L1,L1) + ketbra(op*L2,L2) for op in err])
U = U + U.dag()
Pc = I - Pe

class params(object):
    def __init__(self):
        # Parameters
        self.g = 0.1
        self.gamma = 0.1
        self.gec = 1
        self.delta = 10
    def rho0(self):
        return ketbra(L1)
    def Ht(self):
        #Hamiltonian and changes
        #Might cause wrong error correction because L1 and L2 rotate
        H0 = -self.delta*(ketbra(L1)+ketbra(L2))
        #H0 = self.delta*ketbra(L3)
        V = self.g/2 * (ketbra(L1,L3) + ketbra(L2,L3))
        V = V + V.dag()
        return H0 + V
    def Ld(self):
        ld = lindblad_dissipator(tensor(sigmam(),qeye(2),qeye(2)))
        # Add upwords dissipation
        ld += lindblad_dissipator(tensor(sigmap(),qeye(2),qeye(2)))
        return self.gamma * ld
    def Lec(self):
        lec = sprepost(Pc,Pc)+ sprepost(U*Pe,Pe*U) -spre(I)
        return  self.gec * lec
    def printParams(self):
        print 'g: %f\ngamma: %f\ngec: %f\ndelta: %f'%(self.g,self.gamma,self.gec,self.delta)

class rhoResult(object):
    def __init__(self,data,rho,timelist=None):
        if timelist==None:
            timelist = xrange(len(rho))
        self.data = data
        self.rho = rho
        self.timelist = timelist
    def oo(self):
        o1 = expect(ketbra(L1),self.rho)
        o2 = expect(ketbra(L2),self.rho)
        return [o1,o2]
    def pop(self):
        [o1,o2] = self.oo()
        plot(self.timelist, real(o1), 'b',self.timelist, real(o2), 'r')
        xlabel('Time')
        ylabel('Occupation probability')
        title('Occupation of L1 and L2 vs time')        
    def decay(self):
        eigs = [real(b.eigenenergies()[-1]) for b in self.rho]
        xlabel('Time')
        ylabel('biggest eigenvalue')
        title('decay rate')
        plot(self.timelist,eigs)
    def decayrate(self,points=10):
        # for local maxima
        vals = expect(ketbra(L1),self.rho)
        maxi = np.append([0],argrelextrema(vals, np.greater)[0])
        
        t = array([float(real(i)) for i in self.timelist[maxi]])
        v = array([float(real(i)) for i in vals[maxi]])
        
        popt, pcov = curve_fit(func, t[:points], v[:points], p0=(1,0.01, 0.5))
        return popt

def exper(data=params(),eflag=True,cflag=True,time=None,steps=5000):
    c_op_list = []
    if eflag:
        c_op_list.append(data.Ld())
    if cflag:
        c_op_list.append(data.Lec())
    if not time:
        time = 10*2*pi/(data.g**2/data.delta)
    timelist = linspace(0,time,steps)
    out = mesolve(data.Ht(),data.rho0(),timelist,c_op_list,[])
    return rhoResult(data,out.states,timelist)

# %%
out[len(In)-1] = exper()
a = out[len(In)-1]
a.pop()

# %%
a = out[15]
ll = expect(ketbra(L3),a.rho)
plot(a.timelist,real(ll))
print 'g^2/delta: %f'%(a.data.g**2/a.data.delta)
# Out:
# g^2/delta: 0.001000

# %%
class paramsLDecay(params):
    def Ld(self):
        ld = lindblad_dissipator(ketbra(ket('010'),L3))
        ld += lindblad_dissipator(ketbra(ket('100'),L3))
        return self.gamma * ld

# %%
d = paramsLDecay()
out[len(In)-1] = exper(data=d)
a = out[len(In)-1]
a.pop()

# %%
class paramsL3LDecay(paramsLDecay):
    def Ht(self):
        #Hamiltonian and changes
#        H0 = -self.delta*(ketbra(L1)+ketbra(L2))
        H0 = self.delta*ketbra(L3)
        V = self.g/2 * (ketbra(L1,L3) + ketbra(L2,L3))
        V = V + V.dag()
        return H0 + V

# %%
d = paramsL3LDecay()
out[len(In)-1] = exper(data=d)
a = out[len(In)-1]
a.pop()

# %% [markdown]
# ### Let's try shifting the enregies, the sanity check of shifting everything works.

# %%
class paramsShift(params):
    def Ht(self):
        #Hamiltonian and changes
        #Might cause wrong error correction because L1 and L2 rotate
        #H0 = -self.delta*(ketbra(L1)+ketbra(L2))
        H0 = self.delta*(I-ketbra(L1)-ketbra(L2))
        V = self.g/2 * (ketbra(L1,L3) + ketbra(L2,L3))
        V = V + V.dag()
        return H0 + V

# %%
d = paramsShift()
out[len(In)-1] = exper(data=d)
a = out[len(In)-1]
a.pop()

# %%
a = out[73]
ll = expect(ketbra(L3),a.rho)
plot(a.timelist,real(ll))

# %% [markdown]
# ## The all decay is obviously wrong, because the decay from L1 and L2 is uncorrelated...

# %%
class paramsShiftError(params):
    def Ht(self):
        #Hamiltonian and changes
        #Might cause wrong error correction because L1 and L2 rotate
        #H0 = -self.delta*(ketbra(L1)+ketbra(L2))
        H0 = 5*self.delta*(I-ketbra(L1)-ketbra(L2)-ketbra(L3))
        H0 += self.delta*ketbra(L3)
        V = self.g/2 * (ketbra(L1,L3) + ketbra(L2,L3))
        V = V + V.dag()
        return H0 + V

# %%
d = paramsShiftError()
out[len(In)-1] = exper(data=d,steps=10000)
a = out[len(In)-1]
a.pop()

# %%
a = out[78]
ll = expect(ketbra(L3),a.rho)
plot(a.timelist,real(ll))

# %%
d = paramsShiftError()
d.delta = 1
d.gec = 10
out[len(In)-1] = exper(data=d,steps=10000)
a = out[len(In)-1]
a.pop()

# %%
d = paramsShiftError()
d.delta = 10
d.gec = 10
out[len(In)-1] = exper(data=d,steps=10000)
a = out[len(In)-1]
a.pop()

# %%
class paramsShiftErrorDown(params):
    def Ht(self):
        #Hamiltonian and changes
        #Might cause wrong error correction because L1 and L2 rotate
        #H0 = -self.delta*(ketbra(L1)+ketbra(L2))
        H0 = -5*self.delta*(I-ketbra(L1)-ketbra(L2)-ketbra(L3))
        H0 += self.delta*ketbra(L3)
        V = self.g/2 * (ketbra(L1,L3) + ketbra(L2,L3))
        V = V + V.dag()
        return H0 + V

# %%
d = paramsShiftErrorDown()
out[len(In)-1] = exper(data=d,steps=15000)
a = out[len(In)-1]
a.pop()

# %%
out[len(In)-1] = exper(eflag=False)
a = out[len(In)-1]
a.pop()

# %%
a = out[135]
b = out[81]
error = operate(b.data.Ld(),a.rho[200])
time1 = (1j*a.data.Ht()).expm()*error*(-1j*a.data.Ht()).expm()
corr = operate(b.data.Lec(),error)
corr1 = operate(b.data.Lec(),time1)

#print expect(ketbra(L2),a.rho[200])
print 'state:'
printstates(a.rho[200])
print 'error:'
printstates(error)
print 'time evolution'
printstates(time1)
print 'correction'
printstates(corr)
print 'time evolution correction'
printstates(corr1)
# Out:
# state:
# (-0.00) : (0.01 + -0.01i)|L1>+(-1.00 + -0.01i)|L3>+(0.00 + 0.00i)|O+>+(0.03 + 0.01i)|L2>
# (1.00) : (-0.81 + -0.02i)|L1>+(-0.01 + -0.02i)|L3>+(-0.00 + 0.00i)|O+>+(0.02 + -0.59i)|L2>
# error:
# (-0.10) : (-0.81 + -0.02i)|L1>+(-0.01 + -0.02i)|L3>+(-0.00 + 0.00i)|O+>+(0.02 + -0.59i)|L2>
# (0.05) : (-0.80 + 0.08i)|E1>+(0.04 + 0.59i)|e1>
# (0.05) : (0.81 + -0.04i)|E2>+(0.04 + 0.58i)|e2>
# time evolution
# (-0.10) : (0.81 + -0.04i)|L1>+(-0.00 + -0.04i)|L3>+(-0.00 + 0.00i)|O+>+(0.03 + 0.59i)|L2>
# (0.05) : (-0.55 + 0.59i)|E1>+(0.42 + 0.42i)|e1>
# (0.05) : (-0.80 + 0.13i)|E2>+(-0.11 + -0.57i)|e2>
# correction
# (-0.05) : (0.73 + -0.36i)|E2>+(0.28 + 0.51i)|e2>
# (-0.05) : (0.80 + -0.01i)|E1>+(0.01 + -0.59i)|e1>
# (0.10) : (0.81)|L1>+(0.00)|L3>+(-0.00i)|O+>+(0.59i)|L2>
# time evolution correction
# (-0.05) : (0.73 + -0.36i)|E2>+(0.28 + 0.51i)|e2>
# (-0.05) : (0.80 + -0.01i)|E1>+(0.01 + -0.59i)|e1>
# (0.10) : (0.81)|L1>+(0.00)|L3>+(-0.00i)|O+>+(0.59i)|L2>

# %%
a = out[81]
printstates(a.rho[10000])
print 'pass'
error = operate(a.data.Ld(),a.rho[10000])
corr = operate(a.data.Lec(),error)
printstates(error)
print 'pass'
printstates(corr)
# Out:
# (0.02) : (0.01 + 0.05i)|E2>+(1.00)|e2>
# (0.02) : (0.01 + -0.05i)|E1>+(1.00)|e1>
# (0.02) : (1.00)|O+>+(0.00)|L2>
# (0.02) : (1.00)|E2>+(-0.01 + 0.05i)|e2>
# (0.02) : (0.00)|L1>+(1.00)|L3>+(-0.00)|O+>+(0.00)|L2>
# (0.02) : (1.00)|E1>+(-0.01 + -0.05i)|e1>
# (0.36) : (0.00 + 0.06i)|L1>+(-0.01 + -0.00i)|L3>+(0.00)|O+>+(1.00)|L2>
# (0.52) : (1.00)|L1>+(-0.00)|L3>+(0.00 + -0.00i)|O+>+(-0.00 + 0.06i)|L2>
# pass
# (-0.05) : (1.00)|L1>+(-0.00)|L3>+(0.00 + 0.00i)|O+>+(-0.00 + 0.06i)|L2>
# (-0.03) : (-0.00 + -0.06i)|L1>+(0.00 + 0.00i)|L3>+(0.00)|O+>+(-1.00)|L2>
# (0.02) : (0.01 + 0.05i)|E2>+(1.00)|e2>
# (0.02) : (0.01 + -0.05i)|E1>+(1.00)|e1>
# (0.02) : (1.00)|E2>+(-0.01 + 0.05i)|e2>
# (0.02) : (1.00)|E1>+(-0.01 + -0.05i)|e1>
# pass
# (-0.02) : (1.00)|E1>+(-0.01 + -0.05i)|e1>
# (-0.02) : (1.00)|E2>+(-0.01 + 0.05i)|e2>
# (-0.02) : (0.01 + -0.05i)|E1>+(1.00)|e1>
# (-0.02) : (0.01 + 0.05i)|E2>+(1.00)|e2>
# (0.03) : (0.00 + 0.05i)|L1>+(0.00 + 0.00i)|L3>+(0.00)|O+>+(1.00)|L2>
# (0.05) : (1.00)|L1>+(-0.00)|L3>+(-0.00 + 0.00i)|O+>+(-0.00 + 0.05i)|L2>

# %%
prho0 = out[73].rho[200]
class paramsrho(paramsShiftError):
    def rho0(self):
        return prho0
d = paramsrho()
d.g = 0
out[len(In)-1] = exper(data=d,time = 2*pi/(0.1**2/d.delta),steps=1500)
a = out[len(In)-1]
a.pop()

# %%
a.decay()

# %% [markdown]
# Playing with the energy of the error levels, with L1 and L2 positioned at -delta.
# changing '010' to 5*delta fails, or '011'. or '111+001'

# %%
class paramsShiftErrorPlay(params):
    def Ht(self):
        #Hamiltonian and changes
        #Might cause wrong error correction because L1 and L2 rotate
        #H0 = -self.delta*(ketbra(L1)+ketbra(L2))
        H0 = -self.delta*(ketbra(L1)+ketbra(L2)) 
        #H0 += 5*self.delta*ketbra(unify(ket('111')+ket('001')))
        V = self.g/2 * (ketbra(L1,L3) + ketbra(L2,L3))
        V = V + V.dag()
        return H0 + V

# %%
d = paramsShiftErrorPlay()
out[len(In)-1] = exper(data=d,steps=10000)
a = out[len(In)-1]
a.pop()

# %%
a = out[98]
a.decayrate()
# Out:
# array([ 0.18682725,  0.01      ,  0.81317275])

# %%
class paramsAllDecay(params):
    def Ld(self):
        ld = lindblad_dissipator(ketbra(ket('010'),L3))
        ld += lindblad_dissipator(ketbra(ket('100'),L3))
        ld += lindblad_dissipator(ketbra(ket('010'),L1))
        ld += lindblad_dissipator(ketbra(ket('100'),L1))
        ld += lindblad_dissipator(ketbra(ket('011'),L2))
        ld += lindblad_dissipator(ketbra(ket('101'),L2))
        
        #Added lately, remember that the normalization isn't correct
        ld += lindblad_dissipator(ketbra(ket('000'),ket('100')))
        ld += lindblad_dissipator(ketbra(ket('110'),ket('010')))

        return self.gamma * ld

# %%
d = paramsAllDecay()
out[len(In)-1] = exper(data=d)
a = out[len(In)-1]
a.pop()

# %%
ld = lindblad_dissipator(1/sqrt(2)*ketbra(ket('010'),L1))
ld += lindblad_dissipator(1/sqrt(2)*ketbra(ket('011'),L2))
ld +=lindblad_dissipator(1/sqrt(2)*ketbra(ket('010'),L3))

ld += lindblad_dissipator(1/sqrt(2)*ketbra(ket('100'),L1))
ld += lindblad_dissipator(1/sqrt(2)*ketbra(ket('101'),L2))
ld += lindblad_dissipator(1/sqrt(2)*ketbra(ket('100'),L3))

ld += lindblad_dissipator(ketbra(ket('000'),ket('100')))
ld += lindblad_dissipator(ketbra(ket('110'),ket('010')))


ld2 = lindblad_dissipator(tensor(sigmam(),qeye(2),qeye(2)))
ld2 += lindblad_dissipator(tensor(sigmap(),qeye(2),qeye(2)))

printstates(operate(ld2,ketbra(L1,L3)+ketbra(L3,L1)))
# Out:
# (-1.00) : (1.00)|100>
# (-1.00) : (1.00)|110>
# (1.00) : (1.00)|000>
# (1.00) : (1.00)|010>

# %%
printstates(operate(ld,ketbra(L1,L3))+ketbra(L3,L1))
# Out:
# (0.00) : (0.71)|000>+(-0.71i)|110>
# (0.00) : (0.71)|000>+(0.71i)|110>

# %%
print strket(tensor(sigmam(),qeye(2),qeye(2))*L1)
print strket(tensor(sigmam(),qeye(2),qeye(2))*L2)
print strket(tensor(sigmam(),qeye(2),qeye(2))*L3)
print strket(tensor(sigmap(),qeye(2),qeye(2))*L1)
print strket(tensor(sigmap(),qeye(2),qeye(2))*L2)
print strket(tensor(sigmap(),qeye(2),qeye(2))*L3)
# Out:
# (0.71)|100>
# (-0.71)|101>
# (-0.71)|100>
# (0.71)|010>
# (0.71)|011>
# (0.71)|010>

# %%
out[len(In)-1] = exper(eflag=False)
a = out[len(In)-1]
a.pop()

# %%
a = out[66]
printstates(a.rho[100])
# Out:
# (1.00) : (0.66)|000>+(-0.22i)|001>+(0.68 + -0.03i)|110>+(0.22i)|111>

# %%
a = out[66]
printstates(a.rho[1500])
# Out:
# (1.00) : (-0.03i)|000>+(0.71)|001>+(0.03i)|110>+(-0.71)|111>

# %%
kett = [unify(ket('110') + ket('000')),unify(ket('110') - ket('000')),ket('100'),ket('010')]
kett += [unify(ket('111') + ket('001')),unify(ket('111') - ket('001')),ket('101'),ket('011')]
states = ['|L1>','|L3>','|E1>','|E2>','|O+>','|L2>','|e1>','|e2>']
# Out:
# Quantum object: dims = [[2, 2, 2], [1, 1, 1]], shape = [8, 1], type = ket
# Qobj data =
# [[ 0.]
#  [ 1.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]]

# %%
#printstates(operate(params().Lec(),ketbra(unify(ket('010')-ket('011')))))
expect(ketbra(L3),operate(params().Lec(),ketbra(unify(ket('010')-ket('011')))))
# Out:
# 0.0

# %%
d = params()
d.g = 0.1
d.gamma = 0.01
d.gec = 1
d.delta = 1

out[len(In)-1] = exper(data=d,cflag=False)
a = out[len(In)-1]
a.pop()

# %%
d = paramsShiftError()
d.g = 0.1
d.gamma = 0.01
d.gec = 1
d.delta = 1

out[len(In)-1] = exper(data=d,cflag=False)
a = out[len(In)-1]
a.pop()

# %%
class paramsminus(paramsShiftError):
    def Ld(self):
        #ld = lindblad_dissipator(tensor(sigmam(),qeye(2),qeye(2)))
        # Add upwords dissipation
        ld += lindblad_dissipator(tensor(sigmap(),qeye(2),qeye(2)))
        return self.gamma * ld
d.g = 0.1
d.gamma = 0.01
d.gec = 1
d.delta = 1

out[len(In)-1] = exper(data=d,cflag=False)
a = out[len(In)-1]
a.pop()

# %%
class paramsminus(params):
    def Ld(self):
        #ld = lindblad_dissipator(tensor(sigmam(),qeye(2),qeye(2)))
        # Add upwords dissipation
        ld += lindblad_dissipator(tensor(sigmap(),qeye(2),qeye(2)))
        return self.gamma * ld
d.g = 0.1
d.gamma = 0.01
d.gec = 1
d.delta = 1

out[len(In)-1] = exper(data=d,cflag=False)
a = out[len(In)-1]
a.pop()

# %%
A1 = ketbra(L1,L1) + ketbra(L1,L3) + ketbra(L2,L2)
A2 = ketbra(L1,L1) + ketbra(-L1,L3) + ketbra(L2,L2)
class paramsDecayAndCorrection(params):
    def Ld(self):
        return self.gamma/2 * (sprepost(A1,A1.dag()) + sprepost(A2,A2.dag()) - 2*spre(I))
    def Lec(self):
        pass

# %%
d = paramsDecayAndCorrection()
out[len(In)-1] = exper(data=d,cflag=False)
a = out[len(In)-1]
a.pop()

# %%
a = out[232]
def expectL3(a):
    ll = expect(ketbra(L3),a.rho)
    plot(a.timelist,real(ll))
expectL3(a)

# %% [markdown]
# <h3> Interesting phenomenon. Although we see oscillations, the population of L3 is slowly decreasing. we expect without decay the population to be $\left(\frac{g}{\Delta}\right)^2=1e^{-3}$. With decay, it should be of the order of $\left(\frac{g^2}{\Delta\gamma}\right)\left(\frac{g}{\Delta}\right)^2=1e^{-5}$. similar to what we see. Decreasing $\Delta$ by 10 should result in 1000 more population:</h3>

# %%
d = paramsDecayAndCorrection()
d.delta = 1
out[len(In)-1] = exper(data=d,cflag=False,time=50*2*pi/(d.g**2/d.delta))
a = out[len(In)-1]
a.pop()

# %%
a = out[255]
popt = a.decayrate()
print popt
a.pop()
a.data.printParams()
plot(a.timelist,func(a.timelist,*popt))
# Out:
# [  4.99344280e-01   4.92756604e-04   5.00354996e-01]
# g: 0.100000
# gamma: 0.100000
# gec: 1.000000
# delta: 1.000000

# %% [markdown]
# <h3> So decay rate of $5*e^{-4}$, and we expect: $\left(\frac{g}{\Delta}\right)^{2}\gamma$ . Let's try to increase $\Delta$ to 10: we got  $5*e^{-6}$ as expected.

# %%
a = out[246]
expectL3(a)

# %%
d = paramsDecayAndCorrection()
d.delta = 10
out[len(In)-1] = exper(data=d,cflag=False,time=50*2*pi/(d.g**2/d.delta),steps=10000)
a = out[len(In)-1]
a.pop()

# %%
a = out[263]
expectL3(a)

# %%
a = out[263]

class rRtest(rhoResult):
   def decayrate(self,points=10,p0=(1,0.001, 0.5)):
        # for local maxima
        vals = expect(ketbra(L1),self.rho)
        maxi = np.append([0],argrelextrema(vals, np.greater)[0])
        
        t = array([float(real(i)) for i in self.timelist[maxi]])
        v = array([float(real(i)) for i in vals[maxi]])
        
        popt, pcov = curve_fit(func, t[:points], v[:points], p0)
        #plot(t,v)
        return popt
        

nd = rRtest(a.data,a.rho,a.timelist)
popt = nd.decayrate(1000)
print popt
a.pop()
a.data.printParams()
plot(a.timelist,func(a.timelist,*popt))
# Out:
# [  4.99934562e-01   4.99993630e-06   5.00035557e-01]
# g: 0.100000
# gamma: 0.100000
# gec: 1.000000
# delta: 10.000000

# %% [markdown]
# <h3> Decreaseing $\gamma$ to 0.01 should give $5e^{-5}$ in decay rate:

# %%
d = paramsDecayAndCorrection()
d.gamma = 0.01
d.delta = 1
out[len(In)-1] = exper(data=d,cflag=False,time=50*2*pi/(d.g**2/d.delta))
a = out[len(In)-1]
a.pop()

# %%
a = out[278]
popt = a.decayrate()
print popt
a.pop()
a.data.printParams()
plot(a.timelist,func(a.timelist,*popt))
# Out:
# [  4.51287201e-01   5.68947187e-05   5.47092912e-01]
# g: 0.100000
# gamma: 0.010000
# gec: 1.000000
# delta: 1.000000

# %% [markdown]
# <h3> Same goes with decreasing g to 0.01, should give $5e^{-6}$:

# %%
d = paramsDecayAndCorrection()
d.delta = 1
d.g = 0.01
out[len(In)-1] = exper(data=d,cflag=False,time=50*2*pi/(d.g**2/d.delta),steps=10000)
a = out[len(In)-1]
a.pop()

# %%
a = out[283]

nd = rRtest(a.data,a.rho,a.timelist)
popt = nd.decayrate(p0=(1,0.0001, 0.5))
print popt
a.pop()
a.data.printParams()
plot(a.timelist,func(a.timelist,*popt))
# Out:
# [  4.99993338e-01   4.95002477e-06   5.00003630e-01]
# g: 0.010000
# gamma: 0.100000
# gec: 1.000000
# delta: 1.000000

# %% [markdown]
# <h3> What happens in the two regimes $\frac{g^{2}}{\Delta}\ll\gamma$ and vice versa?

# %%
d = paramsDecayAndCorrection()
d.delta = 1
d.g = 0.1
d.gamma = 0.5
out[len(In)-1] = exper(data=d,cflag=False,time=50*2*pi/(d.g**2/d.delta),steps=1000)
a = out[len(In)-1]
#a.pop()
nd = rRtest(a.data,a.rho,a.timelist)
popt = nd.decayrate(p0=(1,0.0001, 0.5))
print popt
a.data.printParams()
a.pop()
plot(a.timelist,func(a.timelist,*popt))
# Out:
# [ 0.49999935  0.00198721  0.50000063]
# g: 0.100000
# gamma: 0.500000
# gec: 1.000000
# delta: 1.000000

# %%
a = out[301]
expectL3(a)

# %%
d = paramsDecayAndCorrection()
d.delta = 1
d.g = 0.1
d.gamma = 0.0001
out[len(In)-1] = exper(data=d,cflag=False,time=1000*2*pi/(d.g**2/d.delta),steps=10000)
a = out[len(In)-1]
#a.pop()
nd = rRtest(a.data,a.rho,a.timelist)
popt = nd.decayrate(p0=(1,0.0001, 0.5))
print popt
a.data.printParams()
a.pop()
plot(a.timelist,func(a.timelist,*popt))
# Out:
# [  1.05478409e-02   2.63369992e-04   9.90406697e-01]
# g: 0.100000
# gamma: 0.000100
# gec: 1.000000
# delta: 1.000000

# %%
a = out[303]
expectL3(a)

# %%
a = out[303]
nd = rRtest(a.data,a.rho,a.timelist)
popt = nd.decayrate(points=1000,p0=(1,0.00005, 0.5))
print popt
a.data.printParams()
a.pop()
plot(a.timelist,func(a.timelist,*popt))
# Out:
# [  4.67435896e-01   5.26018969e-07   5.26055941e-01]
# g: 0.100000
# gamma: 0.000100
# gec: 1.000000
# delta: 1.000000

# %%
a = out[295]
a.pop()

# %% [markdown]
# <h3> Hmm. only 100 times more. My calculation is wrong. What happens without decay? indeed $\left(\frac{g}{\Delta}\right)^2=1e^{-2}$:</h3>

# %%
d = paramsDecayAndCorrection()
d.delta = 1
out[len(In)-1] = exper(data=d,cflag=False,eflag=False)
a = out[len(In)-1]
a.pop()

# %%
expectL3(a)

# %% [markdown]
# <h3> The right calculation is $\left(\frac{g^2}{\Delta\gamma}\right)^{2}$ .Changing the decay reate to be *2 should increase the decay by 4:

# %%
d = paramsDecayAndCorrection()
d.delta = 1
d.gamma = 0.3
out[len(In)-1] = exper(data=d,cflag=False)
a = out[len(In)-1]
a.pop()

# %%
expectL3(a)

# %% [markdown]
# <h3> Doesn't look right.

# %%
d = paramsDecayAndCorrection()
d.delta = 10
d.g = 0.1
d.gamma = 1
out[len(In)-1] = exper(data=d,cflag=False,time=50*2*pi/(d.g**2/d.delta),steps=20000)
a = out[len(In)-1]
#a.pop()
nd = rRtest(a.data,a.rho,a.timelist)
popt = nd.decayrate(p0=(1,0.0001, 0.5))
print popt
a.pop()
a.data.printParams()
plot(a.timelist,func(a.timelist,*popt))
# Out:
# [  1.22898097e-04   8.36583086e-05   9.99938045e-01]
# g: 0.100000
# gamma: 1.000000
# gec: 1.000000
# delta: 10.000000

# %% [markdown]
# <h2> I must look into the fact that gamma=1 causes NO decay. Not sure how to trust the results.

# %%
d = paramsDecayAndCorrection()
d.delta = 10
d.g = 0.1
d.gamma = 2
out[len(In)-1] = exper(data=d,cflag=False,time=50*2*pi/(d.g**2/d.delta),steps=20000)
a = out[len(In)-1]
#a.pop()
nd = rRtest(a.data,a.rho,a.timelist)
popt = nd.decayrate(p0=(1,0.0001, 0.5))
print popt
a.pop()
a.data.printParams()
plot(a.timelist,func(a.timelist,*popt))
# Out:
# [  5.00010716e-01   9.61384734e-05   4.99988029e-01]
# g: 0.100000
# gamma: 2.000000
# gec: 1.000000
# delta: 10.000000

# %%
a = out[321]
expectL3(a)

# %%
d = paramsDecayAndCorrection()
d.delta = 10
d.g = 0.01
d.gamma = 0.1
out[len(In)-1] = exper(data=d,cflag=False,time=2*pi/(d.g**2/d.delta),steps=20000)
a = out[len(In)-1]
#a.pop()
nd = rRtest(a.data,a.rho,a.timelist)
popt = nd.decayrate(p0=(1,0.0001, 0.5))
print popt
a.pop()
a.data.printParams()
plot(a.timelist,func(a.timelist,*popt))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-326-70d5a8b9f4b4> in <module>()
#       3 d.g = 0.01
#       4 d.gamma = 2
# ----> 5 out[len(In)-1] = exper(data=d,cflag=False,time=2*pi/(d.g**2/d.delta),steps=20000)
#       6 a = out[len(In)-1]
#       7 #a.pop()
#
# <ipython-input-265-e51f078f36fa> in exper(data, eflag, cflag, time, steps)
#     120         time = 10*2*pi/(data.g**2/data.delta)
#     121     timelist = linspace(0,time,steps)
# --> 122     out = mesolve(data.Ht(),data.rho0(),timelist,c_op_list,[])
#     123     return rhoResult(data,out.states,timelist)
#
# /usr/lib/python2.7/dist-packages/qutip/mesolve.pyc in mesolve(H, rho0, tlist, c_ops, e_ops, args, options, progress_bar)
#     262                 res = _mesolve_const(H, rho0, tlist, c_ops,
#     263                                      e_ops, args, options,
# --> 264                                      progress_bar)
#     265             elif n_str > 0:
#     266                 # constant hamiltonian but time-dependent collapse
#
# /usr/lib/python2.7/dist-packages/qutip/mesolve.pyc in _mesolve_const(H, rho0, tlist, c_op_list, e_ops, args, opt, progress_bar)
#     690     # call generic ODE code
#     691     #
# --> 692     return _generic_ode_solve(r, rho0, tlist, e_ops, opt, progress_bar)
#     693
#     694
#
# /usr/lib/python2.7/dist-packages/qutip/mesolve.pyc in _generic_ode_solve(r, rho0, tlist, e_ops, opt, progress_bar)
#     887
#     888         if t_idx < n_tsteps - 1:
# --> 889             r.integrate(r.t + dt[t_idx])
#     890
#     891     progress_bar.finished()
#
# /usr/lib/python2.7/dist-packages/scipy/integrate/_ode.pyc in integrate(self, t, step, relax)
#     386             self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     387                                 self._y, self.t, t,
# --> 388                                 self.f_params, self.jac_params)
#     389         except SystemError:
#     390             # f2py issue with tuple returns, see ticket 1187.
#
# /usr/lib/python2.7/dist-packages/scipy/integrate/_ode.pyc in run(self, *args)
#     864             self.acquire_new_handle()
#     865         y1, t, istate = self.runner(*(args[:5] + tuple(self.call_args) +
# --> 866                                     args[5:]))
#     867         if istate < 0:
#     868             warnings.warn('zvode: ' +
#
# KeyboardInterrupt:
