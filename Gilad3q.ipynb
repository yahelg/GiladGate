# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %run '~/Dropbox/Alex/pynote/GiladGate3q.py'

# %%
out = []

# %%
out.append(exper(False,False))
out[-1].showr()

# %%
out.append(exper(True,False))
out[-1].showr()

# %%
out.append(exper(True,True))
out[-1].showr()

# %%
# sm works on all the hilbert space
out.append(exper(True,True,time=pi/dr*100,steps=100000))
out[-1].showr()

# %%
# sm only on the two lower states
out.append(exper(True,True,time=pi/dr,steps=1000))
out[-1].showr()

# %%
# Using experp with discrete correction
out.append(experp(True,True,time=pi/dr))
out[-1].showr()

# %%
# Using experp with discrete correction - sm revised
# %run '~/Dropbox/Alex/pynote/GiladGate3q.py'
out.append(experp(True,True,time=pi/dr))
out[-1].showr()

# %%
# Using experp with discrete correction longer time
# %run '~/Dropbox/Alex/pynote/GiladGate3q.py'
out.append(experp(True,True,time=10*pi/dr,steps=10000))
out[-1].showr()

# %%
a = out[-1]
a.showtarg()
